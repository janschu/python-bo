# %% [markdown]
# Import Statements

# %%
import numpy as np
import re

# %% [markdown]
# Einlesen von CSV Dateien
# - jeder datensatz beinhaltet Daten von einer Höhenstufe

# %%
filename = "./winddata/wind_wdat_geo_10m_BRD_200m.asc"
# Holen der daten
with open(filename, 'r') as datafile:
    for i in range (1,100):
        next(datafile)
    for line in datafile:
        print (re.sub('\s+',' ',line).split())
        break
    print('fertig')
# Out:
# ['-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999', '-999
# ...
